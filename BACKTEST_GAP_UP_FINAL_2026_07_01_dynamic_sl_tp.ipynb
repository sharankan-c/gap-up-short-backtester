# %%
#IMPORT# ===================================

import re
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from scipy.stats import linregress
from ib_insync import IB, Stock, util
from itertools import product

#STRATEGY_PARAMETERS#

STOP_LOSS_PCT   = 0.20  
TAKE_PROFIT_PCT = 0.30   
POSITION_SIZE   = 5000   
FEES            = 10     
ENTRY           = "next_open_2" 
HOLDING_PERIOD  = 2
GAP_THRESHOLD   = 1.15
DATA_PATH       = Path("/Users/holytrader/Desktop/FinViz_Screener")
USE_SECOND_FILTER = False

PCT_COLS  = ["Performance (Week)", "Performance (Month)",
             "Performance (Quarter)", "Change from Open",
             "Gap", "Change", "Float %"]

FILTER    = {
    "Market Cap": (">", 1000),
    "Float %": (">", 0.7)
}


#DATALOADERS#
#IB_API_CONNECTION# ===================================

#find_csv
def load_screener_data(data_path, filters=None):
    records = []
    for f in data_path.glob("GU_*.csv"):
        parts = re.findall(r'\d+', f.name)
        if len(parts) < 3:
            continue

        #add_date_to_csv_file
        df = pd.read_csv(f)
        df["date"] = pd.to_datetime(f"{parts[0]}-{parts[1]}-{parts[2]}", dayfirst=True)
        records.append(df)

    if not records:
        raise FileNotFoundError(f"No GU_*.csv files found in {data_path}")

    #sum_up_all_screened_results
    out = pd.concat(records, ignore_index=True)

    #format_data
    for col in PCT_COLS:
        if col in out.columns and out[col].dtype == 'object':
            out[col] = out[col].str.strip("%").astype(float) / 100

    #calc_additional_data
    out["Open_2_Close"] = (out["Price"] - out["Open"]) / out["Open"]
    out["Open_2_Low"]   = (out["Low"]   - out["Open"]) / out["Open"]
    out["Open_2_High"]  = (out["High"]  - out["Open"]) / out["Open"]

    #filter_function 
    if filters:
        for col, (op, val) in filters.items():
            if col in out.columns:
                if op == ">":   out = out[out[col] > val]
                elif op == ">=": out = out[out[col] >= val]
                elif op == "<":   out = out[out[col] < val]
                elif op == "<=": out = out[out[col] <= val]

    #give_out_screened_filtered_and_sorted_results
    return out.sort_values("date").reset_index(drop=True)

#creating_new_class
class DownloadData:
    #initiating
    def __init__(self, symbol: str, duration: str, ib: IB):
        self.symbol = symbol
        self.duration = duration
        self.ib = ib

    def _fetch(self) -> pd.DataFrame:
        contract = Stock(self.symbol, "SMART", "USD")
        self.ib.qualifyContracts(contract)
        
        #retrieving_historical_data
        bars = self.ib.reqHistoricalData(
            contract, endDateTime="", durationStr=self.duration,
            barSizeSetting="1 day", whatToShow="TRADES", useRTH=True,
        )
        if not bars:
            print(f"[IB] No data for {self.symbol} – skipping")
            return pd.DataFrame()

        #save_historical_data_in_dataframe
        df = util.df(bars)
        df["Ticker"] = self.symbol
        return df


#BACKTEST_ENGINE# ===================================

def backtest(df: pd.DataFrame,
             stop_loss_pct:   float,
             take_profit_pct: float,
             entry:           str,
             holding_period:  int,
             gap_threshold:   float): 

    #copy_dataframe
    df = df.copy().sort_values("date").reset_index(drop=True)
    N = holding_period

    #calc_prev_close
    #identifiy_gap
    #calc_gap_day_performance
    df["prev_close"] = df["close"].shift(1)
    is_gap = df["open"] > (df["prev_close"] * gap_threshold)
    df["gap_performance"] = np.where(is_gap, (df["close"] - df["open"]) / df["open"], np.nan)

    #group_id
    df["gap_group"] = is_gap.cumsum()

    #max_high_for_each_gap
    df["max_high_since_gap"] = df.groupby("gap_group")["high"].cummax()

    #min_low_for_each_gap
    df["min_low_since_gap"] = df.groupby("gap_group")["low"].cummax()

    #define_entry_day
    if "next_open" in entry:
        parts = entry.split("_")
        k = int(parts[-1]) if parts[-1].isdigit() else 1
    else:
        k = 0

    #placeholders_for_forward_metrics
    df["max_high_fwd"] = np.nan
    df["min_low_fwd"]  = np.nan

    #define_next_opening_price
    df["next_open"] = df["open"].shift(-1)
    for i in range(1, 4):
        df[f"next_open_{i}"] = df["open"].shift(-i)

    #create_columns_in_dataframe
    df["entry"] = 0
    df["exit"] = 0
    df["entry_price"] = 0.0
    df["exit_price"] = 0.0
    
    df["exit_reason"] = pd.Series(dtype="object")
    df["trade_id"]    = pd.Series(dtype="object")
    df["exit_day"]    = pd.Series(dtype="object")
    df["entry_day"]   = pd.Series(dtype="object")
    df["exit_idx"]    = pd.Series(dtype="Int64") 
    
    #default_setting_backtest
    in_position = False
    current_entry_idx = None
    last_exit_row = -1
    
    #backtest_loop
    stalking_period = 5
    i = 0
    while i < len(df):
        if not in_position:
            if pd.notna(df["gap_performance"].iloc[i]) and i > last_exit_row:
                entry_idx = i


                for stalking_offset in range(stalking_period):
                    entry_found = False
                    check_idx = entry_idx + stalking_offset

                    if check_idx >= len(df):
                        break
                    
                    #entry:next_open_x_/_close
                    if entry == "next_open":
                        if check_idx + 1 >= len(df): break
                        entry_price = df["next_open"].iloc[check_idx]
                        actual_entry_day = df["date"].iloc[check_idx + 1]
                    elif entry.startswith("next_open_"):
                        day_num = int(entry.split("_")[-1])
                        column_name = f"next_open_{day_num}"
                        if check_idx + day_num >= len(df): break
                        entry_price = df[column_name].iloc[check_idx]
                        actual_entry_day = df["date"].iloc[check_idx + day_num]
                    else: 
                        entry_price = df["close"].iloc[check_idx]
                        actual_entry_day = df["date"].iloc[check_idx]
    
                    if USE_SECOND_FILTER:
                        #second_entry_filter
                        if entry_price < df['max_high_since_gap'].iloc[check_idx]:
                            continue 
    

                    #entry_found
                    entry_found = True
                    break 
                        
                if not entry_found:
                    i += 1
                    continue   
                    
                #entry_data
                df.loc[check_idx, "entry"] = 1
                df.loc[check_idx, "entry_price"] = entry_price
                df.loc[check_idx, "entry_day"] = actual_entry_day

                #datestamp
                date_stamp = pd.Timestamp(df["date"].iloc[check_idx]).strftime("%Y%m%d")
                df.loc[check_idx, "trade_id"] = f"{df['Ticker'].iloc[check_idx]}_{date_stamp}_Entry_{check_idx}"

                current_entry_idx = check_idx
                in_position = True
                i = check_idx + k + 1
                continue

        #exit
        else:
            idx = current_entry_idx + k + 1
            exit_found = False
            entry_price = df["entry_price"].iloc[current_entry_idx]

            #sl_tp
            sl_price = df["max_high_since_gap"].iloc[current_entry_idx] * (1+stop_loss_pct)
            tp_price = entry_price * (1 - take_profit_pct)
            entry_day_idx = current_entry_idx + k
            window_highs = [df["high"].iloc[entry_day_idx]] if entry_day_idx < len(df) else []
            window_lows  = [df["low"].iloc[entry_day_idx]]  if entry_day_idx < len(df) else []

            #assesing current high/low/open
            while idx < len(df) and idx <= (current_entry_idx + k + N):
                current_open = df["open"].iloc[idx]
                current_high = df["high"].iloc[idx]
                current_low  = df["low"].iloc[idx]

                window_highs.append(current_high)
                window_lows.append(current_low)

                #check_exit_conditions
                if current_open >= sl_price:
                    df.loc[idx, ["exit", "exit_price", "exit_reason", "exit_day"]] = [1, current_open, "stop_loss_gap", df["date"].iloc[idx]]
                    exit_found = True; break
                elif current_high >= sl_price:
                    df.loc[idx, ["exit", "exit_price", "exit_reason", "exit_day"]] = [1, sl_price, "stop_loss", df["date"].iloc[idx]]
                    exit_found = True; break
                elif current_open <= tp_price:
                    df.loc[idx, ["exit", "exit_price", "exit_reason", "exit_day"]] = [1, current_open, "take_profit_gap", df["date"].iloc[idx]]
                    exit_found = True; break
                elif current_low <= tp_price:
                    df.loc[idx, ["exit", "exit_price", "exit_reason", "exit_day"]] = [1, tp_price, "take_profit", df["date"].iloc[idx]]
                    exit_found = True; break
                idx += 1

            #time_exit
            if not exit_found:
                idx = int(min(current_entry_idx + k + N, len(df) - 1))
                df.loc[idx, ["exit", "exit_price", "exit_reason", "exit_day"]] = [1, df["close"].iloc[idx], "time_exit", df["date"].iloc[idx]]
                if df["high"].iloc[idx] not in window_highs:
                    window_highs.append(df["high"].iloc[idx])
                    window_lows.append(df["low"].iloc[idx])

            #saving_max_risk_and_reward
            df.loc[current_entry_idx, "max_high_fwd"] = max(window_highs) if window_highs else entry_price
            df.loc[current_entry_idx, "min_low_fwd"]  = min(window_lows) if window_lows else entry_price

            #datestamp
            date_stamp = pd.Timestamp(df["date"].iloc[idx]).strftime("%Y%m%d")
            df.loc[idx, "trade_id"] = f"{df['Ticker'].iloc[idx]}_{date_stamp}_Exit_{current_entry_idx}"
            df.loc[current_entry_idx, "exit_idx"] = idx

            #default_setting
            last_exit_row = idx
            in_position = False
            current_entry_idx = None
            i = idx + 1
            continue 

        i += 1
    return df
    
#TEST_PERFORMANCE# ===================================

def test_performance(df: pd.DataFrame, stop_loss_pct: float, position_size: float, fees: float):
    all_ticker_trades = []

    #test_performance
    for j in range(len(df)):
        #track_entry 
        if df["entry"].iloc[j] == 1:
            trade = {
                "trade_id":    df["trade_id"].iloc[j],
                "Ticker":      df["Ticker"].iloc[j],
                "entry_day":   df["entry_day"].iloc[j],
                "entry_price": df["entry_price"].iloc[j],
                "max_risk":    ((df["max_high_fwd"].iloc[j] / df["entry_price"].iloc[j]) - 1) * position_size,
                "max_reward":  (1 - (df["min_low_fwd"].iloc[j] / df["entry_price"].iloc[j])) * position_size
            }
            
            exit_idx = df["exit_idx"].iloc[j]
            #track_exit
            if pd.notna(exit_idx):
                res = df.iloc[int(exit_idx)]
                trade["exit_day"]    = res["exit_day"]
                trade["exit_price"]  = res["exit_price"]
                trade["exit_reason"] = res["exit_reason"]
                all_ticker_trades.append(trade)

    #sum_all_trades    
    trades_df = pd.DataFrame(all_ticker_trades)
    if trades_df.empty: 
        return trades_df

    #calc_trade_details 
    #give_out_result 
    trades_df["pnl_pct"] = (trades_df["entry_price"] - trades_df["exit_price"]) / trades_df["entry_price"]
    trades_df["trade_pnl"] = (trades_df["pnl_pct"] * position_size) - fees
    trades_df["cum_pnl"] = trades_df["trade_pnl"].cumsum()
    
    trades_df["pnl_r_initial_risk"] = trades_df["trade_pnl"] / (position_size * stop_loss_pct)
    
    return trades_df


#EXECUTION# ===================================

#extract_filtered_data_from_screening_results 
screener_df = load_screener_data(DATA_PATH, filters=FILTER)

#ib_api_connection
util.startLoop()
ib = IB()
ib.connect("127.0.0.1", 7497, clientId=23423)

#download_historical_data_for_every_ticker
results = []
for ticker in screener_df["Ticker"].unique():
    try:
        df_ticker = DownloadData(ticker, "2 Y", ib)._fetch()
        if not df_ticker.empty:
            results.append(df_ticker)
            print(f"✓ {ticker}")
    except Exception as e:
        print(f"✗ {ticker}: {e}")
ib.disconnect()

if not results:
    raise ValueError("No historical market data returned.")

#sum_up_all_trades_in_one_dataframe 
df_all = pd.concat(results, ignore_index=True).sort_values(["Ticker", "date"])

#activate_if_needed_to_adjust_parameters
STOP_LOSS_VARIANTS   = [0.05] 
TAKE_PROFIT_VARIANTS = [0.30] 
ENTRY_VARIANTS       = ["next_open_3"]
HOLDING_VARIANTS     = [3]

#combination_testing
test_comb = list(product(STOP_LOSS_VARIANTS, TAKE_PROFIT_VARIANTS, ENTRY_VARIANTS, HOLDING_VARIANTS))
all_trades = []

#clean_data
#run_backtest_for_ticker
for sl, tp, entry_mode, hold_period in test_comb:
    for symbol, grp in df_all.groupby("Ticker"):
        clean_grp = grp.drop_duplicates(subset=["date"]).reset_index(drop=True)
        backtest_run = backtest(clean_grp, sl, tp, entry_mode, hold_period, GAP_THRESHOLD)

        #test_performance 
        #sum_up_all_trades
        ticker_trades = test_performance(backtest_run, sl, POSITION_SIZE, FEES)
        
        if not ticker_trades.empty:
            ticker_trades["sl"] = sl
            ticker_trades["tp"] = tp
            ticker_trades["entry_mode"] = entry_mode
            ticker_trades["hold_period"] = hold_period
            all_trades.append(ticker_trades)

if all_trades:
    trades = pd.concat(all_trades, ignore_index=True)
else:
    trades = pd.DataFrame()

#sorting_trades 
if not trades.empty:
    trades['exit_day'] = pd.to_datetime(trades['exit_day'])
    trades = trades.sort_values(by='exit_day').reset_index(drop=True)
    trades['cum_pnl_chronological'] = trades['trade_pnl'].cumsum()
    trades['DD'] = trades['cum_pnl_chronological'].shift(1) - trades['max_risk']
    
    wins   = trades[trades['trade_pnl'] > 0]['trade_pnl']
    losses = trades[trades['trade_pnl'] < 0]['trade_pnl']
    exit_counts = trades['exit_reason'].value_counts()


    #VISUALIZATION# ===================================
    fig, axes = plt.subplots(2, 2, figsize=(18, 12))
    ax1, ax2, ax3, ax4 = axes.flatten()

    #equity_curve
    #shows_cum_pnl_chrono
    ax1.plot(trades['exit_day'], trades['cum_pnl_chronological'], color='#2ca02c', linewidth=2.5, label='Equity Curve')
    ax1.set_title('Cumulative PnL Over Time', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Exit Date')
    ax1.set_ylabel('Total Profit/Loss ($)')
    ax1.grid(True, linestyle='--', alpha=0.6)
    ax1.tick_params(axis='x', rotation=45)
    ax1.legend()
    
    #exit_reason
    #exit_counts 
    ax2.pie(exit_counts,
            labels=exit_counts.index,
            autopct='%1.1f%%',
            startangle=140,
            colors=sns.color_palette('viridis', len(exit_counts)),
            wedgeprops={'edgecolor': 'white', 'linewidth': 2},
            textprops={'fontsize': 11})
    ax2.set_title('Distribution of Exit Reasons', fontsize=14, fontweight='bold')

    #pnl_distribution
    ax3.hist(wins,   bins=20, color='#2ca02c', alpha=0.7, label=f'Wins (n={len(wins)})')
    ax3.hist(losses, bins=20, color='#d62728', alpha=0.7, label=f'Losses (n={len(losses)})')
    ax3.axvline(0, color='black', linewidth=1.5, linestyle='--')
    ax3.set_title('PnL Distribution', fontsize=14, fontweight='bold')
    ax3.set_xlabel('Trade PnL ($)')
    ax3.set_ylabel('Frequency')
    ax3.legend()
    ax3.grid(True, linestyle='--', alpha=0.6)

    #rolling_win_rate 
    trades['is_win'] = (trades['trade_pnl'] > 0).astype(int)
    trades['rolling_winrate'] = trades['is_win'].rolling(window=20, min_periods=1).mean() * 100
    ax4.plot(trades['exit_day'], trades['rolling_winrate'], color='#1f77b4', linewidth=2)
    ax4.axhline(50, color='gray', linestyle='--', alpha=0.7, label='50% Line')
    ax4.fill_between(trades['exit_day'], trades['rolling_winrate'], 50,
                     where=trades['rolling_winrate'] >= 50, alpha=0.2, color='#2ca02c')
    ax4.fill_between(trades['exit_day'], trades['rolling_winrate'], 50,
                     where=trades['rolling_winrate'] < 50,  alpha=0.2, color='#d62728')
    ax4.set_title('Rolling Win Rate (20 Trades)', fontsize=14, fontweight='bold')
    ax4.set_xlabel('Exit Date')
    ax4.set_ylabel('Win Rate (%)')
    ax4.set_ylim(0, 100)
    ax4.legend()
    ax4.grid(True, linestyle='--', alpha=0.6)
    ax4.tick_params(axis='x', rotation=45)

    plt.suptitle('Backtest Analysis Dashboard', fontsize=18, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.show()

    #detailed_pnl_distribution 
    fig2, (ax_pnl, ax_r) = plt.subplots(1, 2, figsize=(18, 6))
    sns.histplot(trades['trade_pnl'], bins=40, kde=True, ax=ax_pnl, color='skyblue', edgecolor='black')
    ax_pnl.axvline(0, color='red', linestyle='--', linewidth=2, label='Break Even')
    ax_pnl.axvline(trades['trade_pnl'].median(), color='green', linestyle='-', linewidth=2, 
                label=f"Median: ${trades['trade_pnl'].median():.2f}")
    ax_pnl.set_title('Distribution of Trade PnL ($)', fontsize=15, fontweight='bold')
    ax_pnl.set_xlabel('Profit / Loss ($)')
    ax_pnl.set_ylabel('Number of Trades')
    ax_pnl.legend()
    ax_pnl.grid(axis='y', alpha=0.3)

    sns.kdeplot(trades['pnl_r_initial_risk'], fill=True, color='purple', ax=ax_r)
    ax_r.axvline(0, color='red', linestyle='--', alpha=0.7)
    ax_r.set_title('R-Multiple Density (Risk Units)', fontsize=15, fontweight='bold')
    ax_r.set_xlabel('R (Reward / Risk)')
    ax_r.set_ylabel('Density')
    ax_r.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

    #boxplot
    plt.figure(figsize=(12, 4))
    sns.boxplot(x=trades['trade_pnl'], color='lightgreen')
    plt.title('Trade PnL Spread & Outliers', fontsize=14, fontweight='bold')
    plt.xlabel('PnL ($)')
    plt.grid(axis='x', alpha=0.3)
    plt.show()

    #scatterplot_risk_reward
    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        data=trades, 
        x='max_risk', 
        y='max_reward', 
        hue='trade_pnl', 
        palette='RdYlGn', 
        size='trade_pnl',
        sizes=(40, 300),
        alpha=0.7
    )
    
    line_val = max(trades['max_risk'].max(), trades['max_reward'].max())
    plt.plot([0, line_val], [0, line_val], color='black', linestyle='--', label='1:1 Ratio Line')
    plt.title('Trade Analysis: Max Risk (MAE) vs. Max Reward (MFE)', fontsize=15, fontweight='bold')
    plt.xlabel('Max Risk Taken During Trade ($) [MAE]', fontsize=12)
    plt.ylabel('Max Reward Reached During Trade ($) [MFE]', fontsize=12)
    plt.legend(title="PnL ($)", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True, alpha=0.5)
    plt.tight_layout()
    plt.show()

    #text_summary 
    total_trades  = len(trades)
    win_rate      = (trades['trade_pnl'] > 0).mean() * 100
    total_pnl     = trades['trade_pnl'].sum()
    median_win    = wins.median()   if len(wins)   > 0 else 0
    median_loss   = losses.median() if len(losses) > 0 else 0
    avg_win       = wins.mean()     if len(wins)   > 0 else 0
    avg_loss      = losses.mean()   if len(losses) > 0 else 0
    profit_factor = wins.sum() / abs(losses.sum()) if len(losses) > 0 else float('inf')
    #max_drawdown = (trades['cum_pnl_chronological'] - trades['cum_pnl_chronological'].cummax()).min()
    
    #max_drawdown_based_on_actual_drawdown_troughout_trade
    max_drawdown    = trades['DD'].min()
    
    avg_r         = trades['pnl_r_initial_risk'].mean()
    total_r       = trades['pnl_r_initial_risk'].sum()

    print("=" * 40)
    print("       BACKTEST SUMMARY")
    print("=" * 40)
    print(f"Total Trades:       {total_trades}")
    print(f"Win Rate:           {win_rate:.1f}%")
    print(f"Total PnL:          ${total_pnl:,.2f}")
    print(f"Max Drawdown:       ${max_drawdown:,.2f}")
    print(f"Profit Factor:      {profit_factor:.2f}")
    print(f"Median Win:         ${median_win:,.2f}")
    print(f"Median Loss:        ${median_loss:,.2f}")
    print(f"Avg Win:            ${avg_win:,.2f}")
    print(f"Avg Loss:           ${avg_loss:,.2f}")
    print(f"Avg R:              {avg_r:.2f}R")
    print(f"Total R:            {total_r:.2f}R")
    print("-" * 40)
    print("Exit Reasons:")
    for reason, count in exit_counts.items():
        print(f"  {reason:<20} {count:>4} ({count/total_trades*100:.1f}%)")
    print("=" * 40)
else:
    print("Backtest completed. Zero trades triggered.")
# Out:
# ✓ COUR
# ✓ HUT
# ✓ MU
# Error 200, reqId 11: No security definition has been found for the request, contract: Stock(symbol='FOLD', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='FOLD', exchange='SMART', currency='USD')
# ✓ SOC
# Error 200, reqId 12: No security definition has been found for the request, contract: Stock(symbol='FOLD', exchange='SMART', currency='USD')
# [IB] No data for FOLD – skipping
# ✓ WGO
# ✓ AXIA
# ✓ BIDU
# ✓ CRNX
# ✓ SMR
# Error 200, reqId 25: No security definition has been found for the request, contract: Stock(symbol='HOUS', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='HOUS', exchange='SMART', currency='USD')
# Error 200, reqId 26: No security definition has been found for the request, contract: Stock(symbol='HOUS', exchange='SMART', currency='USD')
# ✓ GLUE
# [IB] No data for HOUS – skipping
# ✓ MBLY
# ✓ MLTX
# ✓ NEOG
# ✓ BE
# ✓ SMPL
# ✓ GMED
# ✓ TLRY
# ✓ QURE
# ✓ OKLO
# ✓ VST
# ✓ RVMD
# Error 200, reqId 51: No security definition has been found for the request, contract: Stock(symbol='DAWN', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='DAWN', exchange='SMART', currency='USD')
# Error 200, reqId 52: No security definition has been found for the request, contract: Stock(symbol='DAWN', exchange='SMART', currency='USD')
# ✓ OPEN
# [IB] No data for DAWN – skipping
# ✓ KC
# ✓ ADPT
# Error 200, reqId 59: No security definition has been found for the request, contract: Stock(symbol='SHCO', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='SHCO', exchange='SMART', currency='USD')
# ✓ TGTX
# Error 200, reqId 60: No security definition has been found for the request, contract: Stock(symbol='SHCO', exchange='SMART', currency='USD')
# [IB] No data for SHCO – skipping
# ✓ ENTG
# ✓ PEN
# ✓ OCUL
# ✓ CRVS
# ✓ KEP
# ✓ UMC
# ✓ SKM
# ✓ NXT
# ✓ AI
# ✓ STEL
# ✓ LRN
# ✓ FFIV
# ✓ ARI
# ✓ WWD
# ✓ DVA
# ✓ PLTR
# ✓ USAS
# ✓ HYMC
# ✓ PWP
# ✓ GLXY
# ✓ VSAT
# ✓ CG
# Error 200, reqId 107: No security definition has been found for the request, contract: Stock(symbol='BITF', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='BITF', exchange='SMART', currency='USD')
# ✓ RBLX
# Error 200, reqId 108: No security definition has been found for the request, contract: Stock(symbol='BITF', exchange='SMART', currency='USD')
# [IB] No data for BITF – skipping
# ✓ NVST
# ✓ BILL
# ✓ EHC
# ✓ VAL
# ✓ QS
# ✓ DT
# Error 200, reqId 123: No security definition has been found for the request, contract: Stock(symbol='TPH', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='TPH', exchange='SMART', currency='USD')
# ✓ ROKU
# Error 200, reqId 124: No security definition has been found for the request, contract: Stock(symbol='TPH', exchange='SMART', currency='USD')
# [IB] No data for TPH – skipping
# ✓ CART
# ✓ SEI
# ✓ AMAT
# ✓ BROS
# ✓ PBI
# ✓ WTTR
# ✓ RSI
# ✓ WING
# ✓ GPN
# ✓ MSGS
# ✓ GRMN
# ✓ TNDM
# ✓ WK
# ✓ HLIT
# ✓ RNG
# ✓ KOS
# ✓ KEYS
# Error 200, reqId 161: No security definition has been found for the request, contract: Stock(symbol='THR', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='THR', exchange='SMART', currency='USD')
# ✓ IOVA
# Error 200, reqId 162: No security definition has been found for the request, contract: Stock(symbol='THR', exchange='SMART', currency='USD')
# [IB] No data for THR – skipping
# ✓ PVLA
# ✓ Q
# ✓ VAC
# ✓ GCT
# ✓ WWW
# ✓ IONQ
# ✓ CELH
# ✓ ARHS
# ✓ OPRA
# ✓ SJM
# ✓ BFLY
# ✓ LMAT
# ✓ SHAK
# ✓ REAL
# ✓ XYZ
# ✓ FIGS
# ✓ ARLO
# ✓ AAOI
# ✓ NFLX
# ✓ MARA
# ✓ VG
# ✓ ASTH
# ✓ NAT
# ✓ LASR
# ✓ AVAV
# ✓ TTD
# ✓ RTO
# ✓ MRVL
# ✓ BHVN
# ✓ DNTH
# ✓ XENE
# ✓ HIMS
# ✓ CAPR
# ✓ PL
# ✓ FLNC
# ✓ EWTX
# ✓ PURR
# ✓ SAIC
# ✓ TMHC
# ✓ ARM
# ✓ MGM
# ✓ NNE
# ✓ INTC
# ✓ NRIX
# ✓ TNGX
# ✓ STX
# ✓ OUST
# ✓ SBSW
# ✓ AXTI
# ✓ HMY
# 173    88.639823 2026-05-05  754.850000  stop_loss_gap -0.016866   -94.329072
# 174   392.743924 2026-05-07   27.900000      time_exit  0.017260    76.297992
# 175   692.941176 2026-05-07  258.640000      time_exit  0.130622   643.109244
# 176   288.543140 2026-05-13   33.760000      time_exit  0.044979   214.893918
# 177   656.208573 2026-05-13   21.304500      stop_loss  0.058573   282.863456
# 178   194.367922 2026-05-14  109.370000      time_exit -0.115907  -589.532701
# 179   952.968842 2026-05-18   70.830000      time_exit  0.167196   825.978836
# 180   925.496350 2026-05-21  121.020000      time_exit  0.174319   861.597189
# 181    20.362829 2026-06-04   30.954000      stop_loss -0.146020  -740.099963
# 182   394.663702 2026-06-09   34.060000      time_exit  0.053363   256.814897
# 183   395.772897 2026-06-09   23.460000      time_exit  0.027766   128.831330
# 184    10.477787 2026-06-09   71.640000      time_exit -0.000838   -14.191115
# 185   220.266209 2026-06-09  114.080000      time_exit  0.020352    91.760412
# 186  1025.510204 2026-06-09    8.250000      time_exit  0.158163   780.816327
# 187   926.544240 2026-06-10  252.590000      time_exit  0.156628   773.138564
# 188   129.295384 2026-06-16   32.160000      time_exit -0.116279  -591.395349
#
#          cum_pnl  pnl_r_initial_risk    sl   tp   entry_mode  hold_period  \
# 0   -2470.567823           -9.882271  0.05  0.3  next_open_3            3
# 1     251.153428            1.004614  0.05  0.3  next_open_3            3
# 2    -159.425287           -0.637701  0.05  0.3  next_open_3            3
# 3     -87.288942           -0.349156  0.05  0.3  next_open_3            3
# 4     654.893617            2.619574  0.05  0.3  next_open_3            3
# 5     409.331912            1.637328  0.05  0.3  next_open_3            3
# 6    -927.390003           -3.709560  0.05  0.3  next_open_3            3
# 7    -325.647389           -1.302590  0.05  0.3  next_open_3            3
# 8     -39.381707           -0.157527  0.05  0.3  next_open_3            3
# 9   -2381.924174            0.354575  0.05  0.3  next_open_3            3
# 10     73.870968            0.295484  0.05  0.3  next_open_3            3
# 11    184.201313            0.736805  0.05  0.3  next_open_3            3
# 12   -175.517241           -0.702069  0.05  0.3  next_open_3            3
# 13    236.316759            0.945267  0.05  0.3  next_open_3            3
# 14  -3823.375786           -5.765806  0.05  0.3  next_open_3            3
# 15     48.712121            0.194848  0.05  0.3  next_open_3            3
# 16     84.433400            0.337734  0.05  0.3  next_open_3            3
# 17    133.000000            0.532000  0.05  0.3  next_open_3            3
# 18     45.609284            0.182437  0.05  0.3  next_open_3            3
# 19   1142.912621            4.571650  0.05  0.3  next_open_3            3
# 20   -137.853881           -0.551416  0.05  0.3  next_open_3            3
# 21    259.146141            1.674286  0.05  0.3  next_open_3            3
# 22    -74.935065           -0.299740  0.05  0.3  next_open_3            3
# 23    106.788321            0.427153  0.05  0.3  next_open_3            3
# 24   -258.397436           -1.033590  0.05  0.3  next_open_3            3
# 25   -420.518265           -1.682073  0.05  0.3  next_open_3            3
# 26    -34.597496           -0.138390  0.05  0.3  next_open_3            3
# 27    115.496758            0.461987  0.05  0.3  next_open_3            3
# 28    572.740214            2.290961  0.05  0.3  next_open_3            3
# 29   -387.932233           -1.551729  0.05  0.3  next_open_3            3
# 30   1016.940192           -0.503890  0.05  0.3  next_open_3            3
# 31    111.732904            0.446932  0.05  0.3  next_open_3            3
# 32    677.881675            2.373793  0.05  0.3  next_open_3            3
# 33   -346.159737           -1.384639  0.05  0.3  next_open_3            3
# 34    -19.193702           -1.081389  0.05  0.3  next_open_3            3
# 35   -175.016502           -0.700066  0.05  0.3  next_open_3            3
# 36    -48.505936           -1.139291  0.05  0.3  next_open_3            3
# 37    859.461600           -0.629914  0.05  0.3  next_open_3            3
# 38    170.256864            0.253874  0.05  0.3  next_open_3            3
# 39    823.978296           -0.141933  0.05  0.3  next_open_3            3
# 40   -456.733901           -0.144863  0.05  0.3  next_open_3            3
# 41   -311.169591           -1.244678  0.05  0.3  next_open_3            3
# 42    139.530070            0.752144  0.05  0.3  next_open_3            3
# 43    694.179982            2.314733  0.05  0.3  next_open_3            3
# 44    438.949268            1.755797  0.05  0.3  next_open_3            3
# 45   1421.454932            2.389907  0.05  0.3  next_open_3            3
# 46    261.017699            1.044071  0.05  0.3  next_open_3            3
# 47    170.152672            0.680611  0.05  0.3  next_open_3            3
# 48   -470.784314           -1.883137  0.05  0.3  next_open_3            3
# 49     27.987149            0.188723  0.05  0.3  next_open_3            3
# 50   -745.214324           -2.980857  0.05  0.3  next_open_3            3
# 51    459.850818            1.158793  0.05  0.3  next_open_3            3
# 52   -269.955752           -1.079823  0.05  0.3  next_open_3            3
# 53     67.519380            0.270078  0.05  0.3  next_open_3            3
# 54    -72.984402           -0.850058  0.05  0.3  next_open_3            3
# 55     25.116153            0.100465  0.05  0.3  next_open_3            3
# 56    319.221979            1.576628  0.05  0.3  next_open_3            3
# 57     77.538620            0.310154  0.05  0.3  next_open_3            3
# 58    325.051546            1.300206  0.05  0.3  next_open_3            3
# 59   -112.241447           -0.448966  0.05  0.3  next_open_3            3
# 60    505.736041            2.022944  0.05  0.3  next_open_3            3
# 61    384.511149            1.538045  0.05  0.3  next_open_3            3
# 62    -23.908206           -0.095633  0.05  0.3  next_open_3            3
# 63    352.543622            1.410174  0.05  0.3  next_open_3            3
# 64    258.502429           -0.002575  0.05  0.3  next_open_3            3
# 65    528.696171            0.576740  0.05  0.3  next_open_3            3
# 66   1370.790375           -0.202658  0.05  0.3  next_open_3            3
# 67   1725.218509            6.900874  0.05  0.3  next_open_3            3
# 68   1035.657802            3.847147  0.05  0.3  next_open_3            3
# 69    617.322637            0.629887  0.05  0.3  next_open_3            3
# 70    486.428229           -0.673862  0.05  0.3  next_open_3            3
# 71    440.518612            1.762074  0.05  0.3  next_open_3            3
# 72    540.816872           -0.548259  0.05  0.3  next_open_3            3
# 73   -251.748837            0.026594  0.05  0.3  next_open_3            3
# 74    279.193303            1.116773  0.05  0.3  next_open_3            3
# 75    444.660268            1.778641  0.05  0.3  next_open_3            3
# 76    114.243506           -0.587097  0.05  0.3  next_open_3            3
# 77   -411.928948           -1.096300  0.05  0.3  next_open_3            3
# 78   -818.848220           -3.275393  0.05  0.3  next_open_3            3
# 79   -314.242003           -1.256968  0.05  0.3  next_open_3            3
# 80   -397.527816           -0.205472  0.05  0.3  next_open_3            3
# 81   1031.350908            1.348684  0.05  0.3  next_open_3            3
# 82   -314.347826           -1.257391  0.05  0.3  next_open_3            3
# 83   -624.035088           -2.496140  0.05  0.3  next_open_3            3
# 84    289.450549            1.157802  0.05  0.3  next_open_3            3
# 85    166.409062            0.395559  0.05  0.3  next_open_3            3
# 86   -836.629466           -4.380528  0.05  0.3  next_open_3            3
# 87    214.017172           -1.258716  0.05  0.3  next_open_3            3
# 88   1852.413631            0.508780  0.05  0.3  next_open_3            3
# 89    371.624475            0.209610  0.05  0.3  next_open_3            3
# 90   -873.918593           -3.495674  0.05  0.3  next_open_3            3
# 91   -349.315696           -1.509211  0.05  0.3  next_open_3            3
# 92   -444.108305           -0.519042  0.05  0.3  next_open_3            3
# 93   -210.205866            0.935610  0.05  0.3  next_open_3            3
# 94    850.754414            3.403018  0.05  0.3  next_open_3            3
# 95    232.509830            2.481768  0.05  0.3  next_open_3            3
# 96   -427.811988           -1.419310  0.05  0.3  next_open_3            3
# 97    687.674419            2.750698  0.05  0.3  next_open_3            3
# 98    548.479378           -1.948714  0.05  0.3  next_open_3            3
# 99   -216.144214           -0.707050  0.05  0.3  next_open_3            3
# 100   325.781606           -0.475515  0.05  0.3  next_open_3            3
# 101  -140.802770           -0.563211  0.05  0.3  next_open_3            3
# 102  1062.188012            5.960000  0.05  0.3  next_open_3            3
# 103    70.000000            0.280000  0.05  0.3  next_open_3            3
# 104   936.540754            3.080527  0.05  0.3  next_open_3            3
# 105   407.985097            0.895135  0.05  0.3  next_open_3            3
# 106  -138.903174            1.034499  0.05  0.3  next_open_3            3
# 107   -67.223265           -0.268893  0.05  0.3  next_open_3            3
# 108   421.794316           -0.476090  0.05  0.3  next_open_3            3
# 109   317.922078            1.271688  0.05  0.3  next_open_3            3
# 110   191.222618            0.764890  0.05  0.3  next_open_3            3
# 111    22.923098            0.932516  0.05  0.3  next_open_3            3
# 112  -142.654216           -1.426686  0.05  0.3  next_open_3            3
# 113   412.323913           -2.599456  0.05  0.3  next_open_3            3
# 114   191.725746            0.766903  0.05  0.3  next_open_3            3
# 115   489.810678            1.959243  0.05  0.3  next_open_3            3
# 116   -86.359215           -1.994733  0.05  0.3  next_open_3            3
# 117  -104.746717           -0.418987  0.05  0.3  next_open_3            3
# 118   731.201157            0.901860  0.05  0.3  next_open_3            3
# 119   353.305007           -0.073278  0.05  0.3  next_open_3            3
# 120  -176.559599            0.538440  0.05  0.3  next_open_3            3
# 121    59.296375            0.237186  0.05  0.3  next_open_3            3
# 122   245.355070            0.981420  0.05  0.3  next_open_3            3
# 123  -566.057575            1.445330  0.05  0.3  next_open_3            3
# 124  -554.120890           -0.819221  0.05  0.3  next_open_3            3
# 125  1665.378982            1.178354  0.05  0.3  next_open_3            3
# 126   575.835860            1.003137  0.05  0.3  next_open_3            3
# 127 -1238.260870           -4.953043  0.05  0.3  next_open_3            3
# 128   177.672399            0.029662  0.05  0.3  next_open_3            3
# 129  -506.046595           -0.376471  0.05  0.3  next_open_3            3
# 130   148.724832            0.594899  0.05  0.3  next_open_3            3
# 131   -45.714286           -0.182857  0.05  0.3  next_open_3            3
# 132   -83.216126           -0.332865  0.05  0.3  next_open_3            3
# 133   541.393504            2.303964  0.05  0.3  next_open_3            3
# 134   -95.894698           -0.383579  0.05  0.3  next_open_3            3
# 135   511.946127            0.291987  0.05  0.3  next_open_3            3
# 136   320.534662           -1.187152  0.05  0.3  next_open_3            3
# 137  1395.622114            1.457085  0.05  0.3  next_open_3            3
# 138  -154.939271           -0.619757  0.05  0.3  next_open_3            3
# 139    44.325578           -0.939471  0.05  0.3  next_open_3            3
# 140    84.264708            1.201636  0.05  0.3  next_open_3            3
# 141    73.584182            0.643492  0.05  0.3  next_open_3            3
# 142  -444.672720           -0.521723  0.05  0.3  next_open_3            3
# 143  1929.962269            0.310195  0.05  0.3  next_open_3            3
# 144  -282.908820            0.751502  0.05  0.3  next_open_3            3
# 145   -15.913661           -0.063655  0.05  0.3  next_open_3            3
# 146  -359.825467           -1.439302  0.05  0.3  next_open_3            3
# 147  -140.872483           -0.563490  0.05  0.3  next_open_3            3
# 148   294.399727            1.177599  0.05  0.3  next_open_3            3
# 149  -217.385070           -0.970005  0.05  0.3  next_open_3            3
# 150   122.152589            0.488610  0.05  0.3  next_open_3            3
# 151   255.435661            1.021743  0.05  0.3  next_open_3            3
# 152  -563.067346            0.243871  0.05  0.3  next_open_3            3
# 153   836.825612            0.596605  0.05  0.3  next_open_3            3
# 154  -480.279720           -1.921119  0.05  0.3  next_open_3            3
# 155   643.632406            2.117556  0.05  0.3  next_open_3            3
# 156  -191.027668           -0.764111  0.05  0.3  next_open_3            3
# 157   690.409454            1.603836  0.05  0.3  next_open_3            3
# 158   406.503715            1.626015  0.05  0.3  next_open_3            3
# 159  1163.960494            0.909679  0.05  0.3  next_open_3            3
# 160  -369.326474            1.503551  0.05  0.3  next_open_3            3
# 161   287.818340            0.841119  0.05  0.3  next_open_3            3
# 162  1792.517604            0.508554  0.05  0.3  next_open_3            3
# 163   377.583304            1.510333  0.05  0.3  next_open_3            3
# 164   528.014465            1.580058  0.05  0.3  next_open_3            3
# 165   251.802575            1.007210  0.05  0.3  next_open_3            3
# 166   -11.729091            2.169567  0.05  0.3  next_open_3            3
# 167  1488.399957           -1.216471  0.05  0.3  next_open_3            3
# 168   543.333439            2.743951  0.05  0.3  next_open_3            3
# 169    89.967224            0.359869  0.05  0.3  next_open_3            3
# 170 -1433.024699           -2.236424  0.05  0.3  next_open_3            3
# 171   429.589765            1.626667  0.05  0.3  next_open_3            3
# 172 -1145.899539           -1.237080  0.05  0.3  next_open_3            3
# 173   -94.329072           -0.377316  0.05  0.3  next_open_3            3
# 174   120.623570            0.305192  0.05  0.3  next_open_3            3
# 175   875.619074            2.572437  0.05  0.3  next_open_3            3
# 176   263.606039            0.859576  0.05  0.3  next_open_3            3
# 177   282.863456            1.131454  0.05  0.3  next_open_3            3
# 178  -589.532701           -2.358131  0.05  0.3  next_open_3            3
# 179  1989.939330            3.303915  0.05  0.3  next_open_3            3
# 180  1039.269588            3.446389  0.05  0.3  next_open_3            3
# 181  -751.829054           -2.960400  0.05  0.3  next_open_3            3
